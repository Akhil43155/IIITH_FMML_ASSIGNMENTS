# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-14 19:05:09--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   122MB/s    in 0.6s
#
# 2023-05-14 19:05:14 (122 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 39048  1612.08153v1  Human identification remains to be one of the ...    cs
# 22841  1708.05258v1  Choosing the best-performing optimizer(s) out ...  stat
# 10860  1503.00269v2  Improvement guarantees for semi-supervised cla...  stat
# 18129  cs/0405031v1  Normally a decision support system is build to...    cs
# 797    1602.07868v3  We present weight normalization: a reparameter...    cs
# ...             ...                                                ...   ...
# 22407  1606.00832v1  We propose a nonconvex estimator for joint mul...  stat
# 7758   1803.01814v2  Over the past few years batch-normalization ha...  stat
# 9754   1711.01921v3  Text-based analysis methods allow to reveal pr...    cs
# 7683   1802.08246v1  We study the bias of generic optimization meth...  stat
# 22188  1507.01661v1  The dictionary-aided sparse regression (SR) ap...  stat
#
#                                                    title  year  \
# 39048  EgoReID: Cross-view Self-Identification and Hu...  2016
# 22841  Comprehensive Feature-Based Landscape Analysis...  2017
# 10860  Contrastive Pessimistic Likelihood Estimation ...  2015
# 18129  Adaptation of Mamdani Fuzzy Inference System U...  2004
# 797    Weight Normalization: A Simple Reparameterizat...  2016
# ...                                                  ...   ...
# 22407  High Dimensional Multivariate Regression and P...  2016
# 7758   Norm matters: efficient and accurate normaliza...  2018
# 9754   $A^{4}NT$: Author Attribute Anonymity by Adver...  2017
# 7683   Characterizing Implicit Bias in Terms of Optim...  2018
# 22188  Semiblind Hyperspectral Unmixing in the Presen...  2015
#
#                                                 keywords
# 39048  [identification, challenging, community, diffe...
# 22841  [performing, portfolio, optimization, algorith...
# 10860  [improvement, guarantees, supervised, classifi...
# 18129  [decisions, knowledge, containing, information...
# 797    [normalization, reparameterization, decouples,...
# ...                                                  ...
# 22407  [nonconvex, estimator, multivariate, regressio...
# 7758   [normalization, performance, applications, una...
# 9754   [attributes, compromise, anonymous, sensitive,...
# 7683   [optimization, including, different, potential...
# 22188  [dictionary, regression, promising, alternativ...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 39048    [identification, challenging, community, diffe...
# 22841    [performing, portfolio, optimization, algorith...
# 10860    [improvement, guarantees, supervised, classifi...
# 18129    [decisions, knowledge, containing, information...
# 797      [normalization, reparameterization, decouples,...
#                                ...
# 27419    [recognizing, recognition, interaction, catego...
# 39659    [regularized, regression, structural, individu...
# 6646     [instances, alternatives, lightweight, estimat...
# 12183    [addresses, instability, asynchronous, optimiz...
# 35140    [predicate, definitions, modification, practic...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8881 words.
# Out of those 4614 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="c43287d4-a724-4faf-8354-3f4cc9a668da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c43287d4-a724-4faf-8354-3f4cc9a668da")) {                    Plotly.newPlot(                        "c43287d4-a724-4faf-8354-3f4cc9a668da",                        [{"x":["literature","identities","identification","efficiency","conditions","reasoning","occlusion","geometric","different","exploring","community","surveillance","popularity","experimental","viewpoints","drastically","egocentric","challenging","demonstrates","corresponding","considered","approaches","complicated","graphical","introduce","comprehensible","interface","visualization","independent","numerical","landscapes","facilitates","landscape","effective","techniques","expensive","convenient","understanding","objective","advantageous","properties","exploratory","providing","essential","difficult","continuous","portfolio","introduces","optimization","comprehensive","constrained","ingredient","evaluations","characterizing","unfortunately","especially","collection","functions","selection","algorithms","simultaneously","sophisticated","underlying","platforms","algorithm","performing","supervised","estimates","likelihood","improvement","improvements","classifier","counterpart","parameter","potential","resilient","principle","pessimistic","restrictive","solutions","particular","classifiers","demonstrate","contrastive","experiments","unlabeled","essentially","therefore","estimation","classification","explicitly","currently","guarantees","conservative","engineers","demonstrating","information","scientists","difference","knowledge","imprecise","heuristics","containing","adaptation","intelligent","decisions","simulation","inference","reparameterizing","reparameterization","decouples","convergence","sensitive","successfully","conditioning","generative","minibatch","reinforcement","accelerate","computational","modelling","usefulness","stochastic","dependencies","normalization","recurrent","recognition","permitting","direction","applications","regression","including","theoretical","variables","generalized","multivariate","presented","asymptotic","coefficients","simultaneous","estimating","clustering","penalized","operations","structure","responses","coordinate","simulations","randomized","intervening","observing","statistics","sufficiency","inferring","overlapping","observational","identifiability","acyclicity","concerning","collected","scientific","phenomenon","faithfulness","investigated","incorporating","relationships","discovery","determined","generating","establish","integrating","assumption","distribution","quantitatively","straightforward","transformations","discretize","notoriously","trajectory","validating","autoencoders","dimensional","deterministic","stochasticity","variances","outperform","architectures","architectural","regressors","alternatives","prediction","marginalization","penalizes","trajectories","represented","variational","connected","conditional","multimodality","intractable"],"y":[115,7,110,174,134,117,32,57,772,39,78,33,27,364,20,10,8,267,57,129,115,430,27,50,330,3,35,27,125,85,6,19,15,245,334,59,12,152,172,7,190,7,71,71,147,99,3,73,320,67,68,5,60,21,36,114,63,215,162,552,113,22,116,40,777,87,189,71,71,151,111,152,16,134,145,8,52,0,8,150,276,124,546,12,609,54,16,122,222,500,79,67,59,4,5,37,688,13,70,350,11,44,62,73,56,62,77,216,1,2,3,100,47,96,17,127,3,117,19,322,50,32,95,41,38,161,381,3,64,383,117,241,171,128,69,25,173,21,37,28,59,148,6,70,331,25,17,38,21,1,19,63,0,28,25,6,5,0,14,68,35,17,0,49,67,74,52,41,102,57,35,66,212,34,27,34,3,7,26,6,15,164,47,6,9,104,132,12,6,19,249,4,2,25,82,51,73,90,2,23],"type":"bar"},{"x":["literature","identities","identification","efficiency","co ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4614,), (4614, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7958333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>An</span> <span style=''>Extreme</span> <span style=''>Learning</span> <span style=''>Machine</span> <span style=''>Approach</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Predicting</span> <span style=''>Near</span> <span style=''>Chaotic</span> <span style=''>HCCI</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Combustion</span> <span style=''>Phasing</span> <span style=''>in</span> <span style=''>Real</span> <span style=''>Time</span> <br/><br/><span style=''>Fuel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Homogeneous</span> <span style=''>Charge</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Compression</span> <span style=''>Ignition</span> <span style=''>(HCCI)</span> <span style=''>engine</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combustion</span> <span style=''>timing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>must</span> <span style=''>contend</span> <span style=''>with</span> <span style=''>non</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>chemistry</span> <span style=''>non</span> <span style=''>linear</span> <span style=''>physics</span> <span style=''>period</span> <span style=''>doubling</span> <span style=''>bifurcation(s)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>turbulent</span> <span style=''>mixing</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>that</span> <span style=''>can</span> <span style=''>drift</span> <span style=''>day</span> <span style=''>to</span> <span style=''>day</span> <span style=''>and</span> <span style=''>air</span> <span style=''>fuel</span> <span style=''>mixture</span> <span style=''>state</span> <span style='background-color:rgba(0, 255, 0, 0.31423113658070667);'>information</span> <span style=''>that</span> <span style=''>cannot</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style=''>be</span> <span style=''>resolved</span> <span style=''>on</span> <span style=''>a</span> <span style=''>cycle</span> <span style=''>to</span> <span style=''>cycle</span> <span style=''>basis</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>especially</span> <span style=''>during</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>transients</span> <span style=''>In</span> <span style=''>previous</span> <span style=''>work</span> <span style=''>an</span> <span style=''>abstract</span> <span style=''>cycle</span> <span style=''>to</span> <span style=''>cycle</span> <span style=''>mapping</span> <span style=''>function</span> <span style=''>coupled</span> <span style=''>with</span> <span style=''>epsilon</span> <span style=''>Support</span> <span style=''>Vector</span> <span style='background-color:rgba(255, 0, 0, 0.5073684210526316);'>Regression</span> <span style=''>was</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>predict</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experimentally</span> <span style=''>observed</span> <span style=''>cycle</span> <span style=''>to</span> <span style=''>cycle</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combustion</span> <span style=''>timing</span> <span style=''>over</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>range</span> <span style=''>of</span> <span style=''>engine</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>despite</span> <span style=''>some</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>aforementioned</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficulties</span> <span style=''>The</span> <span style=''>main</span> <span style='backgro ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Closed</span> <span style=''>form</span> <span style=''>marginal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>in</span> <span style=''>Gamma</span> <span style=''>Poisson</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorization</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>novel</span> <span style=''>understandings</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Gamma</span> <span style=''>Poisson</span> <span style=''>(GaP)</span> <span style=''>model</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorization</span> <span style=''>model</span> <span style=''>for</span> <span style=''>count</span> <span style=''>data</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>GaP</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>rewritten</span> <span style=''>free</span> <span style=''>of</span> <span style=''>the</span> <span style=''>scoreactivation</span> <span style=''>matrix</span> <span style=''>This</span> <span style=''>gives</span> <span style=''>us</span> <span style=''>new</span> <span style=''>insights</span> <span style=''>about</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>topicdictionary</span> <span style=''>matrix</span> <span style=''>by</span> <span style=''>maximum</span> <span style=''>marginal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>this</span> <span style=''>explains</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>robustness</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>to</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>specified</span> <span style=''>values</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorization</span> <span style=''>rank</span> <span style=''>and</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>its</span> <span style=''>ability</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatically</span> <span style=''>prune</span> <span style=''>spurious</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>columns</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirically</span> <span style=''>observed</span> <span style=''>in</span> <span style=''>previous</span> <span style=''>work</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>marginalization</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>activation</span> <span style=''>matrix</span> <span style=''>leads</span> <span style=''>in</span> <span style=''>turn</span> <span style=''>to</span> <span style=''>a</span> <span style=''>new</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Expectation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Maximization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>favorable</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Regret</span> <span style=''>Bound</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variation</span> <span style=''>for</span> <span style=''>Online</span> <span style=''>Convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <br/><br/><span style=''>In</span> <span style=''>citepHazan</span> <span style=''>2008</span> <span style=''>extract</span> <span style=''>the</span> <span style=''>authors</span> <span style=''>showed</span> <span style=''>that</span> <span style=''>the</span> <span style=''>regret</span> <span style=''>of</span> <span style=''>online</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>can</span> <span style=''>be</span> <span style=''>bounded</span> <span style=''>by</span> <span style=''>the</span> <span style=''>total</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>cost</span> <span style=''>vectors</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>extend</span> <span style=''>this</span> <span style=''>result</span> <span style=''>to</span> <span style=''>general</span> <span style=''>online</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>We</span> <span style=''>first</span> <span style=''>analyze</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>limitations</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>in</span> <span style=''>citepHazan</span> <span style=''>2008</span> <span style=''>extract</span> <span style=''>when</span> <span style=''>applied</span> <span style=''>it</span> <span style=''>to</span> <span style=''>online</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>We</span> <span style=''>then</span> <span style=''>present</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>online</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>whose</span> <span style=''>regrets</span> <span style=''>are</span> <span style=''>bounded</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variation</span> <span style=''>of</span> <span style=''>cost</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>We</span> <span style=''>finally</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>bandit</span> <span style=''>setting</span> <span style=''>and</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3000000000000001);'>randomized</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>online</span> <span style=''>bandit</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variation</span> <span style=''>based</span> <span style=''>regret</span> <span style=''>bound</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>regret</span> <span style=''>bound</span> <span style=''>for</span> <span style=''>online</span> <span style=''>bandit</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>is</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Ultra</span> <span style=''>High</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonlinear</span> <span style=''>Feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <span style=''>for</span> <span style=''>Big</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Biological</span> <span style=''>Data</span> <br/><br/><span style=''>Machine</span> <span style=''>learning</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>used</span> <span style=''>to</span> <span style=''>discover</span> <span style=''>complex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationships</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>biological</span> <span style=''>and</span> <span style=''>medical</span> <span style=''>data</span> <span style=''>However</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sophisticated</span> <span style=''>learning</span> <span style=''>models</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computationally</span> <span style=''>unfeasible</span> <span style=''>for</span> <span style=''>data</span> <span style=''>with</span> <span style=''>millions</span> <span style=''>of</span> <span style=''>features</span> <span style=''>Here</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style=''>first</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>that</span> <span style=''>can</span> <span style=''>scale</span> <span style=''>up</span> <span style=''>to</span> <span style=''>large</span> <span style=''>ultra</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>biological</span> <span style=''>data</span> <span style=''>More</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specifically</span> <span style=''>we</span> <span style=''>scale</span> <span style=''>up</span> <span style=''>the</span> <span style=''>novel</span> <span style=''>Hilbert</span> <span style=''>Schmidt</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Independence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Criterion</span> <span style=''>Lasso</span> <span style=''>(HSIC</span> <span style=''>Lasso)</span> <span style=''>to</span> <span style=''>handle</span> <span style=''>millions</span> <span style=''>of</span> <span style=''>features</span> <span style=''>with</span> <span style=''>tens</span> <span style=''>of</span> <span style=''>thousand</span> <span style=''>samples</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>method</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guaranteed</span> <span style=''>to</span> <span style=''>find</span> <span style=''>an</span> <span style=''>optimal</span> <span style=''>subset</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style=''>features</span> <span style=''>with</span> <span style=''>minimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>redundancy</span> <span style=''>yielding</span> <span style=''>higher</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style=''>power</span> <span style=''>and</span> <span style=''>improved</span> <span style='back ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13055954088952654)
# 	processing (0.10222381635581061)
# 	knowledge (0.12553802008608322)
# 	representation (0.12984218077474893)
# 	segmentation (0.0742467718794835)
# 	information (0.2467718794835007)
# 	detection (0.13127690100430417)
# 	convolutional (0.1373744619799139)
# 	recognition (0.1366571018651363)
# 	different (0.2769010043041607)
#
# Some Statistics words are:
# 	estimation (0.16650099403578528)
# 	theoretical (0.15308151093439365)
# 	variables (0.14165009940357853)
# 	statistical (0.1525844930417495)
# 	stochastic (0.139662027833002)
# 	distribution (0.18290258449304175)
# 	algorithm (0.38916500994035785)
# 	inference (0.20029821073558648)
# 	dimensional (0.18886679920477137)
# 	regression (0.1779324055666004)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="20b0ed9f-c4fb-4e41-9be0-1f88e274e07e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20b0ed9f-c4fb-4e41-9be0-1f88e274e07e")) {                    Plotly.newPlot(                        "20b0ed9f-c4fb-4e41-9be0-1f88e274e07e",                        [{"x":["literature","identities","identification","efficiency","conditions","reasoning","occlusion","geometric","different","exploring","community","surveillance","popularity","experimental","viewpoints","drastically","egocentric","challenging","demonstrates","corresponding","considered","approaches","complicated","graphical","introduce","comprehensible","interface","visualization","independent","numerical","landscapes","facilitates","landscape","effective","techniques","expensive","convenient","understanding","objective","advantageous","properties","exploratory","providing","essential","difficult","continuous","portfolio","introduces","optimization","comprehensive","constrained","ingredient","evaluations","characterizing","unfortunately","especially","collection","functions","selection","algorithms","simultaneously","sophisticated","underlying","platforms","algorithm","performing","supervised","estimates","likelihood","improvement","improvements","classifier","counterpart","parameter","potential","resilient","principle","pessimistic","restrictive","solutions","particular","classifiers","demonstrate","contrastive","experiments","unlabeled","essentially","therefore","estimation","classification","explicitly","currently","guarantees","conservative","engineers","demonstrating","information","scientists","difference","knowledge","imprecise","heuristics","containing","adaptation","intelligent","decisions","simulation","inference","reparameterizing","reparameterization","decouples","convergence","sensitive","successfully","conditioning","generative","minibatch","reinforcement","accelerate","computational","modelling","usefulness","stochastic","dependencies","normalization","recurrent","recognition","permitting","direction","applications","regression","including","theoretical","variables","generalized","multivariate","presented","asymptotic","coefficients","simultaneous","estimating","clustering","penalized","operations","structure","responses","coordinate","simulations","randomized","intervening","observing","statistics","sufficiency","inferring","overlapping","observational","identifiability","acyclicity","concerning","collected","scientific","phenomenon","faithfulness","investigated","incorporating","relationships","discovery","determined","generating","establish","integrating","assumption","distribution","quantitatively","straightforward","transformations","discretize","notoriously","trajectory","validating","autoencoders","dimensional","deterministic","stochasticity","variances","outperform","architectures","architectural","regressors","alternatives","prediction","marginalization","penalizes","trajectories","represented","variational","connected","conditional","multimodality","intractable","distributions","predicting","equivalents","convolutional","qualitatively","parametrized","uncertainty","conflicting","outperforms","maximization","indicator","approximation","procedure","efficiently","implemented","described","classical","traditional","hypothesis","meanwhile","generally","maximizing","significantly","principles","characters","programming","empirical","efficient","hypothesized","performance","compressed","dimensions","achieving","processing","representation","dimensionality","important","guarantee","furthermore","typically","embeddings","scalability","reconstruction","distances","reduction","embedding","experimentally","preprocessing","application","preserves","leverages","contribution","is ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	pessimistic
# 	sufficiency
# 	acyclicity
# 	faithfulness
# 	circularity
# 	practitioner
# 	calculable
# 	sustainability
# 	renewable
# 	forecasted
# 	psychiatric
# 	exoplanet
# 	confounders
# 	distributionally
# 	mcallester
# 	exponents
# 	resolvable
# 	kontorovich
# 	unmeasured
# 	depression
# Some words which never appear in Statistics papers:
# 	identities
# 	permitting
# 	possession
# 	descriptive
# 	irregularities
# 	monocular
# 	occlusions
# 	registrations
# 	diffeomorphic
# 	deformation
# 	discarded
# 	minimalist
# 	intentional
# 	productive
# 	wikipedias
# 	deblurring
# 	deblurred
# 	intentions
# 	analogical
# 	commonsense

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.077491229149997e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7666666666666667
